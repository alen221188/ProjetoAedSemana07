# %% [markdown]
# SPRINT 1 — IMPORTAÇÃO DOS DADOS

# %% [markdown]
# *   IMPORTANDO AS LIBS

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns  
from datetime import datetime

print(" Bibliotecas importadas com sucesso!")  
print(f"   pandas:     {pd.__version__}")  
print(f"   numpy:      {np.__version__}")  
print(f"   matplotlib: {plt.matplotlib.__version__}")  
print(f"   seaborn:    {sns.__version__}")  
print("-" * 50)
# Out:
#  Bibliotecas importadas com sucesso!
#    pandas:     3.0.3
#    numpy:      2.4.6
#    matplotlib: 3.10.9
#    seaborn:    0.13.2
# --------------------------------------------------

# %% [markdown]
# *   LEITURA DA BASE DE DADOS - CSV
#
#     -- Para realizar a leitura do arquivo foi utilizado: o UTF-8 por suportar acentos e caracteres especiais;
#
#     -- Para tabulação dos dados foi utilizado: sep ";" que é o separador utilizado na base dados.

# %%
df = pd.read_csv('Base Varejo.csv', sep=";", encoding="UTF8")
print("DataFrame carregado, Leitura concluída:")

print(f"\nDimensões do DataFrame: {df.shape}") 

print(f"\n{df.shape[0]}, linhas | {df.shape[1]} colunas") 
print('-'*50)
# Out:
# DataFrame carregado, Leitura concluída:
#
# Dimensões do DataFrame: (830000, 14)
#
# 830000, linhas | 14 colunas
# --------------------------------------------------

# %% [markdown]
# *   EXPLORAÇÃO INICIAL DOS DADOS
#
#     -- Realizada a leitura das 5 primeiras linhas com o df.head() e 5 últimas df.tail();
#
#     -- De forma adicional foi realizada uma leitura de linhas aleatórias do DataFrame utilizando df.sample(5)

# %%
print("Iniciando a Exploração Inicial dos Dados")
print('-'*50)

print("\n5 Primeiras linhas")
display(df.head())
print('-'*50)

print("\n5 Últimas linhas")
display(df.tail())
print('-'*50)

print("\n5 Linhas aleatórias")
display(df.sample(5))
print('-'*50)
# Out:
# Iniciando a Exploração Inicial dos Dados
# --------------------------------------------------
#
# 5 Primeiras linhas
#          DATA  CO_ID  CL_ID CL_GENERO  CL_EC  CL_FHL CL_SEG  PR_ID     PR_CAT  \
# 0  01/02/2019   1000    534         M      4       1      C     67    BEBIDAS
# 1  01/02/2019   1000    534         M      4       1      C     70    BEBIDAS
# 2  01/02/2019   1000    534         M      4       1      C    178    HIGIENE
# 3  01/02/2019   1000    534         M      4       1      C      4  ALIMENTOS
# 4  01/02/2019   1000    534         M      4       1      C    175    LIMPEZA
#
#                 PR_NOME  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0  REFRIGERANTE GUARANA          NaN          NaN          NaN          NaN
# 1   REFRIGERANTE OUTROS          NaN          NaN          NaN          NaN
# 2       LENCO UMEDECIDO          NaN          NaN          NaN          NaN
# 3               ABACAXI          NaN          NaN          NaN          NaN
# 4     LIMPADOR MULTIUSO          NaN          NaN          NaN          NaN
# --------------------------------------------------
#
# 5 Últimas linhas
#               DATA   CO_ID  CL_ID CL_GENERO  CL_EC  CL_FHL CL_SEG  PR_ID  \
# 829995  19/08/2022  919822    155         F      2       0      B    183
# 829996  19/08/2022  919822    155         F      2       0      B     56
# 829997  19/08/2022  919822    155         F      2       0      B    227
# 829998  19/08/2022  919822    155         F      2       0      B    214
# 829999  19/08/2022  919822    155         F      2       0      B     59
#
#            PR_CAT           PR_NOME  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 829995  ALIMENTOS           KETCHUP          NaN          NaN          NaN
# 829996  ALIMENTOS  QUEIJO MUSSARELA          NaN          NaN          NaN
# 829997  ALIMENTOS             ARROZ          NaN          NaN          NaN
# 829998  ALIMENTOS            CEBOLA          NaN          NaN          NaN
# 829999  ALIMENTOS        SALGADINHO          NaN          NaN          NaN
#
#         Unnamed: 13
# 829995          NaN
# 829996          NaN
# 829997          NaN
# 829998          NaN
# 829999          NaN
# --------------------------------------------------
#
# 5 Linhas aleatórias
#               DATA   CO_ID  CL_ID CL_GENERO  CL_EC  CL_FHL CL_SEG  PR_ID  \
# 677860  22/01/2022  753374    735         F      4       0      B     16
# 525923  06/01/2021  579028    963         M      3       0      B    202
# 660714  30/12/2021  734104    616         F      1       2      C    123
# 432429  17/01/2021  475413    686         F      3       2      A     77
# 438688  23/01/2021  483078    741         M      3       0      B    176
#
#            PR_CAT             PR_NOME  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 677860  ALIMENTOS  BIFE DE COXAO MOLE          NaN          NaN          NaN
# 525923    LIMPEZA     DESENGORDURANTE          NaN          NaN          NaN
# 660714    LIMPEZA         TIRA MANCHA          NaN          NaN          NaN
# 432429    HIGIENE             FIXADOR          NaN          NaN          NaN
# 438688    LIMPEZA        LIMPA VIDROS          NaN          NaN          NaN
#
#         Unnamed: 13
# 677860          NaN
# 525923          NaN
# 660714          NaN
# 432429          NaN
# 438688          NaN
# --------------------------------------------------

# %% [markdown]
# * INFORMAÇÕES SOBRE O DATAFRAME

# %%
print("\n Informações Gerais do DataFrame")
print('-'*50)
df.info()
print('-'*100)
print('\n')

print("Estatísticas Descritivas (colunas numéricas):")  
print('-'*50)
display(df.describe())  


print("Valores Nulos:")  
print('-'*50)
display(df.isnull().sum().to_frame(name="Nulos"))
# Out:
#  Informações Gerais do DataFrame
# --------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 830000 entries, 0 to 829999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   DATA         830000 non-null  str
#  1   CO_ID        830000 non-null  int64
#  2   CL_ID        830000 non-null  int64
#  3   CL_GENERO    830000 non-null  str
#  4   CL_EC        830000 non-null  int64
#  5   CL_FHL       830000 non-null  int64
#  6   CL_SEG       830000 non-null  str
#  7   PR_ID        830000 non-null  int64
#  8   PR_CAT       830000 non-null  str
#  9   PR_NOME      830000 non-null  str
#  10  Unnamed: 10  0 non-null       float64
#  11  Unnamed: 11  0 non-null       float64
#  12  Unnamed: 12  0 non-null       float64
#  13  Unnamed: 13  0 non-null       float64
# dtypes: float64(4), int64(5), str(5)
# memory usage: 88.7 MB
# ----------------------------------------------------------------------------------------------------
#
#
# Estatísticas Descritivas (colunas numéricas):
# --------------------------------------------------
#               CO_ID          CL_ID          CL_EC        CL_FHL  \
# count  830000.00000  830000.000000  830000.000000  830000.00000
# mean   460045.08989     499.595204       2.596911       1.14654
# std    265465.24754     287.568253       1.170599       1.41696
# min      1000.00000       1.000000       1.000000       0.00000
# 25%    233117.00000     254.000000       2.000000       0.00000
# 50%    456517.00000     498.000000       3.000000       0.00000
# 75%    690132.00000     746.000000       4.000000       2.00000
# max    919822.00000    1000.000000       5.000000       4.00000
#
#                PR_ID  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count  830000.000000          0.0          0.0          0.0          0.0
# mean      115.051855          NaN          NaN          NaN          NaN
# std        66.129241          NaN          NaN          NaN          NaN
# min         1.000000          NaN          NaN          NaN          NaN
# 25%        58.000000          NaN          NaN          NaN          NaN
# 50%       115.000000          NaN          NaN          NaN          NaN
# 75%       172.000000          NaN          NaN          NaN          NaN
# max       229.000000          NaN          NaN          NaN          NaN
# Valores Nulos:
# --------------------------------------------------
#               Nulos
# DATA              0
# CO_ID             0
# CL_ID             0
# CL_GENERO         0
# CL_EC             0
# CL_FHL            0
# CL_SEG            0
# PR_ID             0
# PR_CAT            0
# PR_NOME           0
# Unnamed: 10  830000
# Unnamed: 11  830000
# Unnamed: 12  830000
# Unnamed: 13  830000

# %% [markdown]
# SPRINT 2 — TRANSFORMAÇÃO DE STRINGS, INTEGER, FLOAT E DATETIME

# %% [markdown]
# * INDENTIFICANDO TIPOS DE DADOS DO DATAFRAME

# %%
print("\nVerificando os tipos de dados")
display(df.dtypes.to_frame(name="Tipo de dados"))
# Out:
# Verificando os tipos de dados
#             Tipo de dados
# DATA                  str
# CO_ID               int64
# CL_ID               int64
# CL_GENERO             str
# CL_EC               int64
# CL_FHL              int64
# CL_SEG                str
# PR_ID               int64
# PR_CAT                str
# PR_NOME               str
# Unnamed: 10       float64
# Unnamed: 11       float64
# Unnamed: 12       float64
# Unnamed: 13       float64

# %% [markdown]
# * REMOÇÃO DE COLUNAS COMPLETAMENTE NULAS

# %%
 #--- 1. Remoção de colunas completamente nulas ---  
colunas_nulas = df.columns[df.isnull().all()].tolist()  

print(f"\nColunas completamente nulas (serão removidas):")  
print(f"   {colunas_nulas}")  

# Justificativa: colunas Unnamed com 0 valores úteis  
# não agregam informação — remoção reduz uso de memória  
df_limpo = df.dropna(axis=1, how='all')
# Out:
# Colunas completamente nulas (serão removidas):
#    ['Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13']

# %% [markdown]
# * CONVERSÃO DA COLUNA DATA (str → datetime)

# %%
print("\nConversão da coluna DATA:")  
print(f"   Tipo ANTES : {df['DATA'].dtype}")  

# Usando o datetime do pandas  
df_limpo['DATA'] = pd.to_datetime(df['DATA'], dayfirst=True) 
print(f"   Tipo DEPOIS: {df_limpo['DATA'].dtype}")  


# Extraindo componentes de data 
df_limpo['ANO'] = df_limpo['DATA'].dt.year  
df_limpo['MES'] = df_limpo['DATA'].dt.month  
df_limpo['DIA'] = df_limpo['DATA'].dt.day 

print(f"\nPeríodo da base:")  
print(f"      Data inicial : {df_limpo['DATA'].min().strftime('%d/%m/%Y')}")  
print(f"      Data final   : {df_limpo['DATA'].max().strftime('%d/%m/%Y')}")  
print("-" * 50)
# Out:
# Conversão da coluna DATA:
#    Tipo ANTES : str
#    Tipo DEPOIS: datetime64[us]
#
# Período da base:
#       Data inicial : 04/01/2019
#       Data final   : 08/12/2022
# --------------------------------------------------

# %% [markdown]
# * MAPEAMENTO ESTADO CIVIL (int -> str)
#     - Construção de um dicionário para categorizar o Estado Civil
#
#     -- Justificativa: Fazer uma análise de categorias analisando valores inteiros não é prático.
#
#     -- Por se tratar de um conjuntos de chaves e valores o dicionário se aplica perfeitamente

# %%
print("\nTransformação CL_EC (Estado Civil):")  

dicionario_estado_civil = {  
    1: "Casado ou União Estável",  
    2: "Divorciado",  
    3: "Separado",  
    4: "Solteiro",  
    5: "Viúvo"  
}  

df_limpo["CL_EC"] = df_limpo["CL_EC"].map(dicionario_estado_civil)  

print("Estado civil mapeado!")  
display(dicionario_estado_civil)

#Verificando tipos após transformação 

print("\nTipos DEPOIS da transformação:")  
display(df_limpo.dtypes.to_frame(name="Tipo"))
# Out:
# Transformação CL_EC (Estado Civil):
# Estado civil mapeado!
# {1: 'Casado ou União Estável',
#  2: 'Divorciado',
#  3: 'Separado',
#  4: 'Solteiro',
#  5: 'Viúvo'}
# Tipos DEPOIS da transformação:
#                      Tipo
# DATA       datetime64[us]
# CO_ID               int64
# CL_ID               int64
# CL_GENERO             str
# CL_EC                 str
# CL_FHL              int64
# CL_SEG                str
# PR_ID               int64
# PR_CAT                str
# PR_NOME               str
# ANO                 int32
# MES                 int32
# DIA                 int32

# %% [markdown]
# SPRINT 3 — LIMPEZA DE NULOS E DUPLICATAS

# %% [markdown]
# * TRATANDO A COLUNA PR_CAT
#
#    * Tratamento de PR_CAT com if/else
#
#         Justificativa da escolha if/else:
#
#             * Precisamos checar MÚLTIPLAS condições ao mesmo tempo:
#             - Valor '#N/D'  -> erro vindo do Excel
#             - Valor NaN     -> nulo real do Pandas
#             - Valor ''      -> string vazia
#             - O .replace() sozinho não cobre todos esses casos!

# %%
# Fazendo o tratamento da coluna de categoria de produto, há diversos registros com mesmo PR_ID sem categoria definida
def tratar_categoria(valor):
    if pd.isna(valor):  
        return "Sem Categoria"  
    elif valor == "#N/D": 
        return "Sem Categoria"  
    elif valor.strip() == "": 
        return "Sem Categoria"  
    else:  
        return valor

# Aplicando a função em PR_CAT e PR_NOME  
df_limpo["PR_CAT"]  = df_limpo["PR_CAT"].apply(tratar_categoria)  
df_limpo["PR_NOME"] = df_limpo["PR_NOME"].apply(tratar_categoria)

print("Categorias após tratamento (PR_CAT):")  
print(df_limpo["PR_CAT"].unique())  
print("-" * 50)
# Out:
# Categorias após tratamento (PR_CAT):
# <StringArray>
# [      'BEBIDAS',       'HIGIENE',     'ALIMENTOS',       'LIMPEZA',
#     'ACESSORIOS',           'PET', 'Sem Categoria']
# Length: 7, dtype: str
# --------------------------------------------------

# %% [markdown]
# * VALIDAÇÃO DA REGRA DE NEGÓCIO DO CO_ID

# %%
#Validação da Regra de Negócio do CO_ID

print("\nValidação do CO_ID (Número da Nota Fiscal):")  
total_registros   = len(df_limpo)  
co_id_unicos      = df_limpo["CO_ID"].nunique()  
co_id_repetidos   = total_registros - co_id_unicos  

print(f"   Total de registros  : {total_registros:,}")  
print(f"   CO_IDs únicos       : {co_id_unicos:,}")  
print(f"   CO_IDs que repetem  : {co_id_repetidos:,}") 
print("-" * 50)

produtos_por_compra = df_limpo.groupby("CO_ID").size()  
print(f"\n    Regra de Negócio identificada:")  
print(f"      Média de produtos por nota  : {produtos_por_compra.mean():.2f}")  
print(f"      Máx. produtos em uma nota   : {produtos_por_compra.max()}")  
print(f"      Mín. produtos em uma nota   : {produtos_por_compra.min()}")  
print(f"\n   ATENÇÃO: CO_ID se repete pois uma nota fiscal")  
print(f"      pode conter vários produtos — comportamento ESPERADO!")  
print("-" * 50)
# Out:
# Validação do CO_ID (Número da Nota Fiscal):
#    Total de registros  : 830,000
#    CO_IDs únicos       : 18,471
#    CO_IDs que repetem  : 811,529
# --------------------------------------------------
#
#     Regra de Negócio identificada:
#       Média de produtos por nota  : 44.94
#       Máx. produtos em uma nota   : 89
#       Mín. produtos em uma nota   : 1
#
#    ATENÇÃO: CO_ID se repete pois uma nota fiscal
#       pode conter vários produtos — comportamento ESPERADO!
# --------------------------------------------------

# %% [markdown]
# * VERIFICANDO DUPLICATAS

# %%
print("\n🔍 Verificação de Linhas Duplicadas:")  
duplicatas = df_limpo.duplicated().sum()  
print(f"   Total de linhas duplicadas: {duplicatas}")  

if duplicatas > 0:  
    df_limpo = df_limpo.drop_duplicates()  
    print(f"{duplicatas} duplicatas removidas!")  
else:  
    print("Nenhuma duplicata encontrada!")  

print("-" * 50)
# Out:
# 🔍 Verificação de Linhas Duplicadas:
#    Total de linhas duplicadas: 96553
# 96553 duplicatas removidas!
# --------------------------------------------------

# %% [markdown]
# * ANÁLISE DE PRODUTOS SEM CATEGORIA

# %%
print("\nDistribuição por Categoria (após limpeza):")  
display(df_limpo['PR_CAT'].value_counts().sort_values(ascending=True))
# Out:
# Distribuição por Categoria (após limpeza):
# PR_CAT
# Sem Categoria      3228
# ACESSORIOS        12871
# PET               28553
# BEBIDAS           38264
# LIMPEZA          128632
# HIGIENE          137702
# ALIMENTOS        384197
# Name: count, dtype: int64

# %% [markdown]
# * SPRINT 4 — ESTATÍSTICA DESCRITIVA (CL_FHL) - Nº de Filhos dos clientes

# %%
print("=== ESTATÍSTICAS BÁSICAS — CL_FHL ===")  
print("   CL_FHL = Número de Filhos do Cliente")  
print("=" * 50) 

filhos = df_limpo["CL_FHL"]

#Consolidação dos parâmetros estatísticos

print(f"\nPARÂMETROS ESTATÍSTICOS:")  
print(f"   {'Contagem':<20}: {filhos.count():>12,.0f}")  #Conta quantos valores existem no dataset 
print(f"   {'Média':<20}: {filhos.mean():>12.2f}")  # Calcula a média aritmética (soma ÷ quantidade) 
print(f"   {'Mediana':<20}: {filhos.median():>12.2f}")  # Encontra o valor do meio quando ordenado
print(f"   {'Moda':<20}: {filhos.mode()[0]:>12.0f}")  # Identifica o valor que aparece com mais frequência
print(f"   {'Desvio Padrão':<20}: {filhos.std():>12.2f}")  # Mede a dispersão dos dados em relação à média
print(f"   {'Variância':<20}: {filhos.var():>12.2f}")  # O quadrado do desvio padrão (dispersão ao quadrado)
print(f"   {'Mínimo':<20}: {filhos.min():>12.0f}")  # Menor valores do conjunto
print(f"   {'Máximo':<20}: {filhos.max():>12.0f}")  # Maior valores do conjunto
print(f"   {'Q1 (25%)':<20}: {filhos.quantile(0.25):>12.2f}")  # Quartis — dividem os dados em 4 partes iguais (25%)
print(f"   {'Q2 (50%)':<20}: {filhos.quantile(0.50):>12.2f}")  # Quartis — dividem os dados em 4 partes iguais (50%)
print(f"   {'Q3 (75%)':<20}: {filhos.quantile(0.75):>12.2f}")  # Quartis — dividem os dados em 4 partes iguais (75%)
print(f"   {'Amplitude':<20}: {filhos.max() - filhos.min():>12.0f}")  # Diferença entre máximo e mínimo
print("-" * 50)  

print("\nResumo via describe():")  
display(filhos.describe())
# Out:
# === ESTATÍSTICAS BÁSICAS — CL_FHL ===
#    CL_FHL = Número de Filhos do Cliente
# ==================================================
#
# PARÂMETROS ESTATÍSTICOS:
#    Contagem            :      733,447
#    Média               :         1.15
#    Mediana             :         0.00
#    Moda                :            0
#    Desvio Padrão       :         1.42
#    Variância           :         2.01
#    Mínimo              :            0
#    Máximo              :            4
#    Q1 (25%)            :         0.00
#    Q2 (50%)            :         0.00
#    Q3 (75%)            :         2.00
#    Amplitude           :            4
# --------------------------------------------------
#
# Resumo via describe():
# count    733447.000000
# mean          1.146049
# std           1.416917
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           2.000000
# max           4.000000
# Name: CL_FHL, dtype: float64

# %%
# ============================================================
# ANÁLISE COMPLEMENTAR — Distribuição de Compras
# ============================================================

print("\n" + "=" * 60)
print("ANÁLISE DE DISTRIBUIÇÃO DE COMPRAS")
print("=" * 60)

# --- 1. Categoria Dominante ---
print("\nCategoria Mais Vendida:")
categoria_vendas = df_limpo['PR_CAT'].value_counts()
categoria_dominante = categoria_vendas.index[0]
vendas_categoria_dominante = categoria_vendas.iloc[0]

print(f"   Categoria: {categoria_dominante}")
print(f"   Quantidade de compras: {vendas_categoria_dominante:,}")
print(f"   Percentual: {(vendas_categoria_dominante/len(df_limpo))*100:.1f}%")
print("\n   Top 5 Categorias:")
for idx, (cat, qtd) in enumerate(categoria_vendas.head().items(), 1):
    pct = (qtd/len(df_limpo))*100
    print(f"      {idx}. {cat:<30} : {qtd:>10,} ({pct:>5.1f}%)")

print("-" * 60)

# --- 2. Segmento Mais Comprador ---
print("\nSegmentação com Maior Volume de Compras:")
segmento_vendas = df_limpo['CL_SEG'].value_counts()
segmento_dominante = segmento_vendas.index[0]
vendas_segmento_dominante = segmento_vendas.iloc[0]

print(f"   Segmentação: {segmento_dominante}")
print(f"   Quantidade de compras: {vendas_segmento_dominante:,}")
print(f"   Percentual: {(vendas_segmento_dominante/len(df_limpo))*100:.1f}%")
print("\n   Todos as Segmentação:")
for idx, (seg, qtd) in enumerate(segmento_vendas.items(), 1):
    pct = (qtd/len(df_limpo))*100
    print(f"      {idx}. Segmento {seg:<20} : {qtd:>10,} ({pct:>5.1f}%)")

print("-" * 60)

# --- 3. Produto Mais Vendido ---
print("\nProduto Mais Vendido:")
produto_vendas = df_limpo['PR_NOME'].value_counts()
produto_dominante = produto_vendas.index[0]
vendas_produto_dominante = produto_vendas.iloc[0]

print(f"   Produto: {produto_dominante}")
print(f"   Quantidade de compras: {vendas_produto_dominante:,}")
print(f"   Percentual: {(vendas_produto_dominante/len(df_limpo))*100:.1f}%")
print("\n   Top 10 Produtos Mais Vendidos:")
for idx, (prod, qtd) in enumerate(produto_vendas.head(10).items(), 1):
    pct = (qtd/len(df_limpo))*100
    print(f"      {idx:2d}. {prod:<40} : {qtd:>10,} ({pct:>5.1f}%)")

print("-" * 60)
# Out:
# ============================================================
# ANÁLISE DE DISTRIBUIÇÃO DE COMPRAS
# ============================================================
#
# Categoria Mais Vendida:
#    Categoria: ALIMENTOS
#    Quantidade de compras: 384,197
#    Percentual: 52.4%
#
#    Top 5 Categorias:
#       1. ALIMENTOS                      :    384,197 ( 52.4%)
#       2. HIGIENE                        :    137,702 ( 18.8%)
#       3. LIMPEZA                        :    128,632 ( 17.5%)
#       4. BEBIDAS                        :     38,264 (  5.2%)
#       5. PET                            :     28,553 (  3.9%)
# ------------------------------------------------------------
#
# Segmentação com Maior Volume de Compras:
#    Segmentação: B
#    Quantidade de compras: 468,505
#    Percentual: 63.9%
#
#    Todos as Segmentação:
#       1. Segmento B                    :    468,505 ( 63.9%)
#       2. Segmento C                    :    205,265 ( 28.0%)
#       3. Segmento A                    :     59,677 (  8.1%)
# ------------------------------------------------------------
#
# Produto Mais Vendido:
#    Produto: PRESUNTO COZIDO
#    Quantidade de compras: 12,719
#    Percentual: 1.7%
#
#    Top 10 Produtos Mais Vendidos:
#        1. PRESUNTO COZIDO                          :     12,719 (  1.7%)
#        2. SARDINHA                                 :      6,610 (  0.9%)
#        3. BANANA                                   :      6,518 (  0.9%)
#        4. ESCOVA DE DENTE                          :      6,518 (  0.9%)
#        5. GEL                                      :      6,517 (  0.9%)
#        6. PAPINHA INFANTIL                         :      6,515 (  0.9%)
#        7. MODELADOR                                :      6,505 (  0.9%)
#        8. CERA                                     :      6,502 (  0.9%)
#        9. LIMPADOR PERFUMADO                       :      6,501 (  0.9%)
#       10. CEBOLA                                   :      6,501 (  0.9%)
# ------------------------------------------------------------

# %% [markdown]
# *   REALIZANDO AGRUPAMENTOS

# %%
print("\n=== PADRÕES DE AGRUPAMENTO ===")  

print("\nAgrupamento 1: Gênero x Categoria")  
grupo1 = (df_limpo.groupby(["CL_GENERO", "PR_CAT"])["CO_ID"]  
          .count().reset_index(name="QTD")  
          .sort_values("QTD", ascending=False))  
display(grupo1.head(10))  

print("\nAgrupamento 2: Segmentação x Categoria")  
grupo2 = (df_limpo.groupby(["CL_SEG", "PR_CAT"])["CO_ID"]  
          .count().reset_index(name="QTD")  
          .sort_values("QTD", ascending=False))  
display(grupo2.head(10))  

print("\nAgrupamento 3: Ano x Categoria")  
grupo3 = (df_limpo.groupby(["ANO", "PR_CAT"])["CO_ID"]  
          .count().reset_index(name="QTD")  
          .sort_values(["ANO", "QTD"], ascending=[True, False]))  
display(grupo3.head(10))
# Out:
# === PADRÕES DE AGRUPAMENTO ===
#
# Agrupamento 1: Gênero x Categoria
#    CL_GENERO     PR_CAT     QTD
# 1          F  ALIMENTOS  200274
# 8          M  ALIMENTOS  183923
# 3          F    HIGIENE   71721
# 4          F    LIMPEZA   67328
# 10         M    HIGIENE   65981
# 11         M    LIMPEZA   61304
# 2          F    BEBIDAS   19764
# 9          M    BEBIDAS   18500
# 5          F        PET   14809
# 12         M        PET   13744
# Agrupamento 2: Segmentação x Categoria
#    CL_SEG     PR_CAT     QTD
# 8       B  ALIMENTOS  245501
# 15      C  ALIMENTOS  107578
# 10      B    HIGIENE   87943
# 11      B    LIMPEZA   82063
# 17      C    HIGIENE   38433
# 18      C    LIMPEZA   36109
# 1       A  ALIMENTOS   31118
# 9       B    BEBIDAS   24363
# 12      B        PET   18406
# 3       A    HIGIENE   11326
# Agrupamento 3: Ano x Categoria
#      ANO         PR_CAT     QTD
# 1   2019      ALIMENTOS   92062
# 3   2019        HIGIENE   33153
# 4   2019        LIMPEZA   30999
# 2   2019        BEBIDAS    9166
# 5   2019            PET    6832
# 0   2019     ACESSORIOS    3113
# 6   2019  Sem Categoria     778
# 8   2020      ALIMENTOS  100742
# 10  2020        HIGIENE   36223
# 11  2020        LIMPEZA   33895

# %%
# ============================================================
#             RELATÓRIO FINAL E EXPORTAÇÃO
# ============================================================

print("\n")
print("=" * 60)
print("            RELATÓRIO FINAL DO PROJETO")
print("           Análise Exploratória de Dados — Varejo")
print("=" * 60)

print(f"\n BASE DE DADOS:")
print(f"   {'Total de registros pré tratamento':<35}: {len(df):>10,}")
print(f"   {'Total de registros pós tratamento':<35}: {len(df_limpo):>10,}")
print(f"   {'Total de colunas pré tratamento':<35}: {df.shape[1]:>10}")
print(f"   {'Total de colunas pós tratamento':<35}: {df_limpo.shape[1]:>10}")
print(f"   {'Período dos dados':<35}: {df_limpo['DATA'].min().strftime('%d/%m/%Y')} → {df_limpo['DATA'].max().strftime('%d/%m/%Y')}")

print(f"\n LIMPEZA REALIZADA:")
print(f"   {'Colunas nulas removidas':<35}: {len(colunas_nulas):>10}")
print(f"   {'Duplicatas removidas':<35}: {duplicatas:>10}")
print(f"   {'Registros com Sem Categoria':<35}: {(df_limpo['PR_CAT'] == 'Sem Categoria').sum():>10,}")

print(f"\n ESTATÍSTICAS — CL_FHL (Nº de Filhos):")
print(f"   {'Média':<35}: {df_limpo['CL_FHL'].mean():>10.2f}")
print(f"   {'Mediana':<35}: {df_limpo['CL_FHL'].median():>10.2f}")
print(f"   {'Desvio Padrão':<35}: {df_limpo['CL_FHL'].std():>10.2f}")

print(f"\n CATEGORIAS DE PRODUTOS:")
print(f"   {'Categorias únicas':<35}: {df_limpo['PR_CAT'].nunique():>10}")

print(f"\n PERFIL DOS CLIENTES:")
print(f"   {'Clientes únicos':<35}: {df_limpo['CL_ID'].nunique():>10,}")
print(f"   {'% Feminino':<35}: {(df_limpo['CL_GENERO'] == 'F').mean()*100:>9.1f}%")
print(f"   {'% Masculino':<35}: {(df_limpo['CL_GENERO'] == 'M').mean()*100:>9.1f}%")

print("\n" + "=" * 60)
print("  Análise concluída com sucesso!")
print("=" * 60)
# Out:
# ============================================================
#             RELATÓRIO FINAL DO PROJETO
#            Análise Exploratória de Dados — Varejo
# ============================================================
#
#  BASE DE DADOS:
#    Total de registros pré tratamento  :    830,000
#    Total de registros pós tratamento  :    733,447
#    Total de colunas pré tratamento    :         14
#    Total de colunas pós tratamento    :         13
#    Período dos dados                  : 04/01/2019 → 08/12/2022
#
#  LIMPEZA REALIZADA:
#    Colunas nulas removidas            :          4
#    Duplicatas removidas               :      96553
#    Registros com Sem Categoria        :      3,228
#
#  ESTATÍSTICAS — CL_FHL (Nº de Filhos):
#    Média                              :       1.15
#    Mediana                            :       0.00
#    Desvio Padrão                      :       1.42
#
#  CATEGORIAS DE PRODUTOS:
#    Categorias únicas                  :          7
#
#  PERFIL DOS CLIENTES:
#    Clientes únicos                    :      1,000
#    % Feminino                         :      52.1%
#    % Masculino                        :      47.9%
#
# ============================================================
#   Análise concluída com sucesso!
# ============================================================

# %% [markdown]
# * EXPORTANDO O NOVO DATAFRAME

# %%
#Exportando o DataFrame limpo 
import os  
os.makedirs('output', exist_ok=True)  
df_limpo.to_csv('output/df_limpo.csv', index=False, encoding='UTF-8')  
print("\ndf_limpo.csv exportado para a pasta output/")
# Out:
# df_limpo.csv exportado para a pasta output/
